# %%
import matplotlib.pyplot as plt

# %%
# Basic matplotlib
plt.figure()
x1 = [2,4,6, 30,45,60]
x2 = [35,37,36,36,22,1]
plt.plot(x1, label='Anakin Darkside Growth')
plt.plot(x2, label='Younglings')
plt.legend()
plt.show()

# %%
import seaborn as sns

# %%
sns.set(style='whitegrid')
# sns.set_style('whitegrid')
# sns.set_style('darkgrid')
sns.set(font='serif')

# %%
# Using seaborn
plt.figure()
x1 = [2,4,6, 30,45,60]
x2 = [35,37,36,36,22,1]
plt.plot(x1, label='Anakin Darkside Meter')
plt.plot(x2, label='Younglings in Temple', color='red')
plt.legend()
plt.show()
