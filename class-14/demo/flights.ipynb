# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
x1 = [2, 4, 30, 45, 60]
x2 = [35, 37, 36, 22, 1]
plt.plot(x1, label='Anakin Darkside Meter', color='red')
plt.plot(x2, label='Younglings left in the Temple', color='blue')
plt.legend()
plt.show()

# %%
import seaborn as sns

# %%
sns.set(style='dark',font='serif')

# %%
flights = sns.load_dataset('flights')
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
type(flights)
# Out:
# pandas.core.frame.DataFrame

# %%
sns.get_dataset_names()

# %%
sns.relplot(x='year', y='passengers', hue='month', data=flights)

# %%
year_sums = flights.groupby('year', as_index=False).sum()
sns.relplot(x='year', y='passengers', data=year_sums)

# %%
sns.lmplot(x='year', y='passengers', data=year_sums)

# %%
sns.barplot(x='month', y='passengers', data=flights)
print()

# %%
g = sns.barplot(x='month', y='passengers', data=flights, ci=None)
g.set_xticklabels(labels=flights['month'], rotation=45)
print()
